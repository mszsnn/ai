# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## the first world

# %%
t = 1

# %%
type(t)
# Out:
# int

# %%
t= True

# %%
type(t)
# Out:
# bool

# %%
t = ['1', 1, 2, False]

# %%
type(t)
# Out:
# list

# %%
t = {'a':1, 'b':2}

# %%
type(t)
# Out:
# dict

# %%
t = None

# %%
print(t)
# Out:
# None

# %%
type(t)
# Out:
# dict

# %%
a = 1
b = 'abc'

# %%
print('我们数字类型%s， 字符串类型%s' % (a,b) )
# Out:
# 我们数字类型1， 字符串类型abc

# %%
print(f'我们是数字类型{a}, 字符串类型{b}')
# Out:
# 我们是数字类型1, 字符串类型abc

# %%
if a == 1:
    print(a)
elif a== 1 :
    type(b)
# Out:
# 1

# %%
def fun(a):
    print(a)
    return a
    
d = fun(1) 
print(d)
# Out:
# 1
# 1
